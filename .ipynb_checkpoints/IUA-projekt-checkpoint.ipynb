# %%
import pandas as pd
import numpy as np
import pylab as plt

pd.set_option('display.max_rows', None)

personal_train = pd.read_csv("C:\\Users\\jakub\\Desktop\\IAU\\4\\personal_train.csv")
other_train = pd.read_csv("C:\\Users\\jakub\\Desktop\\IAU\\4\\other_train.csv")
other_train
# Out:
#       Unnamed: 0                   name  \
# 0              0         Julie Thompson
# 1              1          Ella Benedict
# 2              2           Nancy Manuel
# 3              3           Diane Watson
# 4              4          Jennifer Luna
# 5              5              Lou Maner
# 6              6           Emily Miller
# 7              7          Sandra Cherry
# 8              8       Ethel Echevarria
# 9              9             Monte Gehl
# 10            10            Kathy Smith
# 11            11               Joe Kies
# 12            12             April Cook
# 13            13           James Spicer
# 14            14       Douglas Mcdaniel
# 15            15         Janice Zediker
# 16            16         Rosemary Menze
# 17            17         Josphine Otani
# 18            18          Norma Dimarco
# 19            19             Billy Read
# 20            20         Terry Tolliver
# 21            21       Linda Grollimund
# ...

# %%
other_train["medical_info"].unique()
# Out:
# array(["{'query hypothyroid':'t','T4U measured':'t','pregnant':'f','thyroid surgery':'f','TSH measured':'t','query on thyroxine':'f','I131 treatment':'f','on thyroxine':'f','T3 measured':'t','psych':'f'}",
#        "{'query hypothyroid':'f','T4U measured':'t','pregnant':'f','thyroid surgery':'f','TSH measured':'t','query on thyroxine':'f','I131 treatment':'f','on thyroxine':'f','T3 measured':'t','psych':'f'}",
#        "{'query hypothyroid':'f','T4U measured':'t','pregnant':'f','thyroid surgery':'f','TSH measured':'t','query on thyroxine':'f','I131 treatment':'f','on thyroxine':'f','T3 measured':'f','psych':'f'}",
#        "{'query hypothyroid':'f','T4U measured':'t','pregnant':'f','thyroid surgery':'f','TSH measured':'t','query on thyroxine':'t','I131 treatment':'f','on thyroxine':'f','T3 measured':'f','psych':'f'}",
# ...

# %%
other_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 34 columns):
# Unnamed: 0                   2287 non-null int64
# name                         2287 non-null object
# address                      2287 non-null object
# query hyperthyroid           2278 non-null object
# FTI measured                 2280 non-null object
# education                    2278 non-null object
# lithium                      2280 non-null object
# TT4                          2126 non-null float64
# T4U                          2044 non-null float64
# capital-loss                 2279 non-null float64
# capital-gain                 2273 non-null float64
# tumor                        2275 non-null object
# TSH                          2036 non-null float64
# T3                           1798 non-null float64
# fnlwgt                       2282 non-null float64
# hours-per-week               2277 non-null float64
# ...

# %%
personal_train.describe()
# Out:
#        Unnamed: 0         age
# count  972.000000  972.000000
# mean   485.500000   51.423868
# std    280.736531   18.966700
# min      0.000000    7.000000
# 25%    242.750000   35.000000
# 50%    485.500000   54.000000
# 75%    728.250000   67.000000
# max    971.000000   93.000000
